# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('ecomm.csv')
df
# Out:
#                          Email                         Address       Avatar  \
# 0    mstephenson@fernandez.com                835 Frank Tunnel          NaN
# 1                  Wrightmouth                  MI 82180-9605"       Violet
# 2            hduke@hotmail.com              4547 Archer Common          NaN
# 3                  Diazchester                  CA 06566-8576"    DarkGreen
# 4             pallen@yahoo.com  24645 Valerie Unions Suite 582          NaN
# ..                         ...                             ...          ...
# 995            South Chadburgh                       TN 56128"     Cornsilk
# 996        cwilson@hotmail.com     680 Jennifer Lodge Apt. 808          NaN
# 997              Brendachester                  TX 05000-5873"         Teal
# 998  hannahwilson@davidson.com   49791 Rachel Heights Apt. 898          NaN
# 999           East Drewborough                  OR 55919-9528"  DarkMagenta
#
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#                        Email                         Address     Avatar  \
# 0  mstephenson@fernandez.com                835 Frank Tunnel        NaN
# 1                Wrightmouth                  MI 82180-9605"     Violet
# 2          hduke@hotmail.com              4547 Archer Common        NaN
# 3                Diazchester                  CA 06566-8576"  DarkGreen
# 4           pallen@yahoo.com  24645 Valerie Unions Suite 582        NaN
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0                  NaN          NaN              NaN                   NaN
# 1            34.497268    12.655651        39.577668              4.082621
# 2                  NaN          NaN              NaN                   NaN
# 3            31.926272    11.109461        37.268959              2.664034
# 4                  NaN          NaN              NaN                   NaN
#
#    Yearly Amount Spent
# 0                  NaN
# 1           587.951054
# ...

# %%
df.tail()
# Out:
#                          Email                        Address       Avatar  \
# 995            South Chadburgh                      TN 56128"     Cornsilk
# 996        cwilson@hotmail.com    680 Jennifer Lodge Apt. 808          NaN
# 997              Brendachester                 TX 05000-5873"         Teal
# 998  hannahwilson@davidson.com  49791 Rachel Heights Apt. 898          NaN
# 999           East Drewborough                 OR 55919-9528"  DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 995            32.646777    11.499409        38.332576              4.958264
# 996                  NaN          NaN              NaN                   NaN
# 997            33.322501    12.391423        36.840086              2.336485
# 998                  NaN          NaN              NaN                   NaN
# 999            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# 995           551.620146
# ...

# %%
df[2:5]
# Out:
#                Email                         Address     Avatar  \
# 2  hduke@hotmail.com              4547 Archer Common        NaN
# 3        Diazchester                  CA 06566-8576"  DarkGreen
# 4   pallen@yahoo.com  24645 Valerie Unions Suite 582        NaN
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 2                  NaN          NaN              NaN                   NaN
# 3            31.926272    11.109461        37.268959              2.664034
# 4                  NaN          NaN              NaN                   NaN
#
#    Yearly Amount Spent
# 2                  NaN
# 3           392.204933
# 4                  NaN

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
df.Email
# Out:
# 0      mstephenson@fernandez.com
# 1                    Wrightmouth
# 2              hduke@hotmail.com
# 3                    Diazchester
# 4               pallen@yahoo.com
#                  ...
# 995              South Chadburgh
# 996          cwilson@hotmail.com
# 997                Brendachester
# 998    hannahwilson@davidson.com
# 999             East Drewborough
# Name: Email, Length: 1000, dtype: object

# %%
df.Address
# Out:
# 0                    835 Frank Tunnel
# 1                      MI 82180-9605"
# 2                  4547 Archer Common
# 3                      CA 06566-8576"
# 4      24645 Valerie Unions Suite 582
#                     ...
# 995                         TN 56128"
# 996       680 Jennifer Lodge Apt. 808
# 997                    TX 05000-5873"
# 998     49791 Rachel Heights Apt. 898
# 999                    OR 55919-9528"
# Name: Address, Length: 1000, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.Address)
# Out:
# pandas.core.series.Series

# %%
df[['Email','Address']]
# Out:
#                          Email                         Address
# 0    mstephenson@fernandez.com                835 Frank Tunnel
# 1                  Wrightmouth                  MI 82180-9605"
# 2            hduke@hotmail.com              4547 Archer Common
# 3                  Diazchester                  CA 06566-8576"
# 4             pallen@yahoo.com  24645 Valerie Unions Suite 582
# ..                         ...                             ...
# 995            South Chadburgh                       TN 56128"
# 996        cwilson@hotmail.com     680 Jennifer Lodge Apt. 808
# 997              Brendachester                  TX 05000-5873"
# 998  hannahwilson@davidson.com   49791 Rachel Heights Apt. 898
# 999           East Drewborough                  OR 55919-9528"
#
# [1000 rows x 2 columns]

# %%
df['Length of Membership'].max()
# Out:
# 744.2218671

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             31.130462    14.350284        33.956926
# std               6.128380     7.327838         9.787361
# min               8.668350     8.508152         0.789520
# 25%              32.086022    11.469670        36.088966
# 50%              32.904773    12.109744        36.943004
# 75%              33.636921    12.992473        37.648456
# max              36.139662    39.220713        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           454.000000
# mean              48.607305           499.919858
# std              144.216919            78.325793
# min                0.269901           266.086341
# 25%                3.014640           445.917049
# 50%                3.653135           498.887875
# 75%                4.534414           549.100737
# max              744.221867           765.518462

# %%
df['Time on Website'].max()
# Out:
# 40.00518164

# %%
df.set_index('Time on App')
# Out:
#                                  Email                         Address  \
# Time on App
# NaN          mstephenson@fernandez.com                835 Frank Tunnel
# 12.655651                  Wrightmouth                  MI 82180-9605"
# NaN                  hduke@hotmail.com              4547 Archer Common
# 11.109461                  Diazchester                  CA 06566-8576"
# NaN                   pallen@yahoo.com  24645 Valerie Unions Suite 582
# ...                                ...                             ...
# 11.499409              South Chadburgh                       TN 56128"
# NaN                cwilson@hotmail.com     680 Jennifer Lodge Apt. 808
# 12.391423                Brendachester                  TX 05000-5873"
# NaN          hannahwilson@davidson.com   49791 Rachel Heights Apt. 898
# 12.418808             East Drewborough                  OR 55919-9528"
#
#                   Avatar  Avg. Session Length  Time on Website  \
# Time on App
# ...

# %%
df1= pd.read_csv('weatherNewyork.csv',parse_dates =["day"])
df1.set_index('day',inplace = True)
df1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df1.fillna(0)
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df1.fillna ({
    'temperature' : 0,
    'windspeed' : 0,
    'event' :'no event'
})
newdf
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
newdf =df1.fillna(method = 'ffill')
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df1.interpolate()
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
newdf = df1.interpolate(method = 'time')
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
newdf = df1.dropna()
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df1.dropna(how = 'all')
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df1.dropna(thresh = 1)
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df2 = pd.read_csv('weater_df.csv')
df2
# Out:
#         day temperature windspeed  event
# 0  01-01-17        32 F     6 mph   Rain
# 1  01-02-17      -99999     7 mph  Sunny
# 2  01-03-17          28    -99999   Snow
# 3  01-04-17      -99999         7      0
# 4  01-05-17        32 F    -99999   Rain
# 5  01-06-17        31 F         2  Sunny
# 6  01-06-17        34 F         5      0

# %%
new_df = df2.replace(-99999,np.nan)
new_df
# Out:
#         day temperature windspeed  event
# 0  01-01-17        32 F     6 mph   Rain
# 1  01-02-17      -99999     7 mph  Sunny
# 2  01-03-17          28    -99999   Snow
# 3  01-04-17      -99999         7      0
# 4  01-05-17        32 F    -99999   Rain
# 5  01-06-17        31 F         2  Sunny
# 6  01-06-17        34 F         5      0

# %%
new_df = df2.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'},'', regex=True) 
new_df
# Out:
#         day temperature windspeed  event
# 0  01-01-17         32         6    Rain
# 1  01-02-17      -99999        7   Sunny
# 2  01-03-17          28    -99999   Snow
# 3  01-04-17      -99999         7      0
# 4  01-05-17         32     -99999   Rain
# 5  01-06-17         31          2  Sunny
# 6  01-06-17         34          5      0

# %%
df3 = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df3
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df3.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %%
df4 = pd.read_csv('weather3.csv')
df4
# Out:
#     day      city temperature  windspeed  event Unnamed: 5
# 0   NaN  01-01-17    new york         32      6       Rain
# 1   NaN  01-02-17    new york         36      7      Sunny
# 2   NaN  01-03-17    new york         28     12       Snow
# 3   NaN  01-04-17    new york         33      7      Sunny
# 4   NaN  01-01-17      mumbai         90      5      Sunny
# 5   NaN  01-02-17      mumbai         85     12        Fog
# 6   NaN  01-03-17      mumbai         87     15        Fog
# 7   NaN  01-04-17      mumbai         92      5       Rain
# 8   NaN  01-01-17       paris         45     20      Sunny
# 9   NaN  01-02-17       paris         50     13     Cloudy
# 10  NaN  01-03-17       paris         54      8     Cloudy
# 11  NaN  01-04-17       paris         42     10     Cloudy

# %%
g = df4.groupby('city')
g

# %%
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# 01-01-17
#    day      city temperature  windspeed  event Unnamed: 5
# 0  NaN  01-01-17    new york         32      6       Rain
# 4  NaN  01-01-17      mumbai         90      5      Sunny
# 8  NaN  01-01-17       paris         45     20      Sunny
# 01-02-17
#    day      city temperature  windspeed  event Unnamed: 5
# 1  NaN  01-02-17    new york         36      7      Sunny
# 5  NaN  01-02-17      mumbai         85     12        Fog
# 9  NaN  01-02-17       paris         50     13     Cloudy
# 01-03-17
#     day      city temperature  windspeed  event Unnamed: 5
# 2   NaN  01-03-17    new york         28     12       Snow
# 6   NaN  01-03-17      mumbai         87     15        Fog
# 10  NaN  01-03-17       paris         54      8     Cloudy
# 01-04-17
#     day      city temperature  windspeed  event Unnamed: 5
# 3   NaN  01-04-17    new york         33      7      Sunny
# 7   NaN  01-04-17      mumbai         92      5       Rain
# ...

# %%
g.max()
# Out:
#           day temperature  windspeed  event Unnamed: 5
# city
# 01-01-17  NaN       paris         90     20      Sunny
# 01-02-17  NaN       paris         85     13      Sunny
# 01-03-17  NaN       paris         87     15       Snow
# 01-04-17  NaN       paris         92     10      Sunny

# %%
g.describe()
# Out:
#            day                              windspeed             ...        \
#          count mean std min 25% 50% 75% max     count       mean  ...   75%
# city                                                              ...
# 01-01-17   0.0  NaN NaN NaN NaN NaN NaN NaN       3.0  55.666667  ...  67.5
# 01-02-17   0.0  NaN NaN NaN NaN NaN NaN NaN       3.0  57.000000  ...  67.5
# 01-03-17   0.0  NaN NaN NaN NaN NaN NaN NaN       3.0  56.333333  ...  70.5
# 01-04-17   0.0  NaN NaN NaN NaN NaN NaN NaN       3.0  55.666667  ...  67.0
#
#                event
#            max count       mean       std  min   25%   50%   75%   max
# city
# 01-01-17  90.0   3.0  10.333333  8.386497  5.0   5.5   6.0  13.0  20.0
# 01-02-17  85.0   3.0  10.666667  3.214550  7.0   9.5  12.0  12.5  13.0
# 01-03-17  87.0   3.0  11.666667  3.511885  8.0  10.0  12.0  13.5  15.0
# 01-04-17  92.0   3.0   7.333333  2.516611  5.0   6.0   7.0   8.5  10.0
#
# [4 rows x 24 columns]

# %%
g.plot()
# Out:
# city
# 01-01-17    AxesSubplot(0.125,0.125;0.775x0.755)
# 01-02-17    AxesSubplot(0.125,0.125;0.775x0.755)
# 01-03-17    AxesSubplot(0.125,0.125;0.775x0.755)
# 01-04-17    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df4 = pd.concat([india_weather, us_weather])
df4
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df5 = pd.concat([india_weather, us_weather], ignore_index=True)
df5
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df6 = pd.concat([india_weather, us_weather], keys=["india", "us"])
df6
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df6.loc["us"]
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df6.loc["india"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df7 = pd.concat([temperature_df,windspeed_df],axis=1)
df7
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df8 = pd.concat([temperature_df,s],axis=1)
df8
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain

# %%
df81 = pd.concat([temperature_df,s],axis=0)
df81
# Out:
#        city  temperature      0
# 0    mumbai         32.0    NaN
# 1     delhi         45.0    NaN
# 2  banglore         30.0    NaN
# 0       NaN          NaN  Humid
# 1       NaN          NaN    Dry
# 2       NaN          NaN   Rain

# %%
import pandas as pd
df11 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df11
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df12 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df12
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df13 = pd.merge(df11, df12, on="city")
df13
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df11 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df11
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df12 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df12
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df13=pd.merge(df11,df12,on="city",how="inner")
df13
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df13=pd.merge(df11,df12,on="city",how="outer")
df13
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %%
df13=pd.merge(df11,df12,on="city",how="left")
df13
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df13=pd.merge(df11,df12,on="city",how="right")
df13
# Out:
#         city  temperature  humidity
# 0   new york         21.0        68
# 1    chicago         14.0        65
# 2  san diego          NaN        71

# %%
df13=pd.merge(df11,df12,on="city",how="outer",indicator=True)
df13
# Out:
#         city  temperature  humidity      _merge
# 0   new york         21.0      68.0        both
# 1    chicago         14.0      65.0        both
# 2    orlando         35.0       NaN   left_only
# 3  baltimore         38.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %%
df11 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df11
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df12 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df12
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df13= pd.merge(df11,df12,on="city",how="outer", suffixes=('_first','_second'))
df13
# Out:
#         city  temperature_first  humidity_first  temperature_second  \
# 0   new york               21.0            65.0                14.0
# 1    chicago               14.0            68.0                21.0
# 2    orlando               35.0            71.0                 NaN
# 3  baltimore               38.0            75.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity_second
# 0             68.0
# 1             65.0
# 2              NaN
# 3              NaN
# 4             71.0

# %%
df11 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df11.set_index('city',inplace=True)
df11
# Out:
#           temperature
# city
# new york           21
# chicago            14
# orlando            35

# %%
df1 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df12.set_index('city',inplace=True)
df12
# Out:
#            temperature  humidity
# city
# chicago             21        65
# new york            14        68
# san diego           35        71

# %%
df11.join(df12,lsuffix='_l', rsuffix='_r')
# Out:
#           temperature_l  temperature_r  humidity
# city
# new york             21           14.0      68.0
# chicago              14           21.0      65.0
# orlando              35            NaN       NaN
